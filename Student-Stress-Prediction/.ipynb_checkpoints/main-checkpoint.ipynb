# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv('student-lifestyle-and-stress-dataset.csv')

# %%
df.head()
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       school     6.868702     1.711722            3.176942         NaN
# 1       school     8.519088     3.251084            3.880787   93.978465
# 2      college     4.498770     6.306885            2.936172   64.421253
# 3       school     8.591223     2.384922            5.222832   81.868960
# 4      college     5.329293     9.345179            7.815869   85.847982
#
#    Exam_Pressure  Family_Support  Month  Stress_Level
# 0            8.0             7.0    2.0             1
# 1            6.0             4.0    3.0             1
# 2            7.0             1.0   12.0             1
# 3            2.0             7.0    7.0             0
# 4            5.0             6.0   10.0             1

# %% [markdown]
# Handling The Missing Values

# %%
df.isnull().sum()
# Out:
# Student_Type          1252
# Sleep_Hours           1333
# Study_Hours           1277
# Social_Media_Hours    1312
# Attendance            1305
# Exam_Pressure         1270
# Family_Support        1291
# Month                 1314
# Stress_Level             0
# dtype: int64

# %%
df.shape
# Out:
# (25500, 9)

# %%
df.dtypes
# Out:
# Student_Type           object
# Sleep_Hours           float64
# Study_Hours           float64
# Social_Media_Hours    float64
# Attendance            float64
# Exam_Pressure         float64
# Family_Support        float64
# Month                 float64
# Stress_Level            int64
# dtype: object

# %%
df.describe()
# Out:
#         Sleep_Hours   Study_Hours  Social_Media_Hours    Attendance  \
# count  24167.000000  24223.000000        24188.000000  24195.000000
# mean       6.458948      4.696477            3.555614     81.270961
# std        1.504228      2.240148            1.901528     12.052045
# min        2.008586     -1.433434            0.000040     -5.000000
# 25%        5.438360      3.078230            2.152249     73.738894
# 50%        6.542566      4.538138            3.500709     81.942959
# 75%        7.531571      6.135670            4.864312     90.106859
# max        9.997527     22.444460            9.962134    120.000000
#
#        Exam_Pressure  Family_Support         Month  Stress_Level
# count   24230.000000    24209.000000  24186.000000  25500.000000
# mean        5.369748        5.798298      6.500992      0.299882
# std         2.394003        2.232371      3.455308      0.458215
# min         1.000000        1.000000      1.000000      0.000000
# 25%         4.000000        4.000000      3.000000      0.000000
# 50%         5.000000        6.000000      6.000000      0.000000
# 75%         7.000000        7.000000     10.000000      1.000000
# max        10.000000       10.000000     12.000000      1.000000

# %%
df['Student_Type'].value_counts()
# Out:
# Student_Type
# college            13391
# school              6021
# working_student     4836
# Name: count, dtype: int64

# %%
df['Student_Type'].isnull().sum()
# Out:
# np.int64(1252)

# %%
df[df["Student_Type"].isna()].head(20)
# Out:
#     Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 21           NaN     4.646379     8.303502            3.019420   98.493938
# 40           NaN     4.907335     6.067431                 NaN   83.260939
# 82           NaN     9.150968     1.242483            1.653746   88.102984
# 84           NaN     7.107427     4.141574            1.575881   95.188464
# 87           NaN     3.991247     6.564631            0.947214   86.969110
# 103          NaN     7.522528     4.454901            5.028889   81.421635
# 174          NaN     8.063624     3.787469            0.882453         NaN
# 226          NaN     9.385518     4.588633            4.407257   70.091599
# 251          NaN     8.347053     5.361303            2.712901   85.242179
# 341          NaN     4.651448     8.239760            2.733169   95.897328
# 359          NaN     4.940605     8.817359            5.154657   74.521197
# 366          NaN     9.201711     6.611324            3.669409   88.824330
# 369          NaN     6.865748     2.036737            3.028039   77.723751
# 393          NaN     7.364950     6.034263            2.918577   80.545689
# 404          NaN     7.916478     2.638653            1.570611   72.125547
# 429          NaN     4.713205          NaN            2.492559   68.990283
# 453          NaN     6.891845     3.388194            5.345824   76.852180
# 504          NaN     5.897056     4.067491            5.296788   71.321971
# 506          NaN     7.072339     3.861403            4.529583   81.905581
# 518          NaN     8.017862     1.183591            6.056207   92.544180
#
#      Exam_Pressure  Family_Support  Month  Stress_Level
# 21             1.0             4.0    5.0             0
# 40             5.0             4.0    7.0             0
# 82             6.0             7.0    8.0             0
# 84             5.0             7.0    NaN             0
# 87             1.0             9.0    6.0             0
# 103            5.0             NaN    1.0             0
# 174            2.0             6.0    6.0             0
# 226            7.0             7.0    4.0             1
# 251            NaN            10.0    5.0             0
# 341            5.0             7.0    8.0             1
# 359            5.0             7.0   11.0             1
# 366            6.0             5.0    2.0             0
# 369            2.0             NaN    1.0             0
# 393            7.0             NaN   12.0             1
# 404            5.0             2.0    6.0             1
# 429            9.0             4.0    7.0             1
# 453            7.0             5.0    8.0             0
# 504            6.0             3.0    1.0             1
# 506            1.0             3.0    3.0             1
# 518           10.0             6.0    3.0             1

# %%
df["Student_Type"].value_counts(normalize=True, dropna=False)
# Out:
# Student_Type
# college            0.525137
# school             0.236118
# working_student    0.189647
# NaN                0.049098
# Name: proportion, dtype: float64

# %%
#Handling Student_type missing value
#replacing those with mode value 
df["Student_Type"] = df["Student_Type"].fillna("college")

# %%
df["Student_Type"].value_counts(normalize=True, dropna=False)
# Out:
# Student_Type
# college            0.574235
# school             0.236118
# working_student    0.189647
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['Student_Type', 'Sleep_Hours', 'Study_Hours', 'Social_Media_Hours',
#        'Attendance', 'Exam_Pressure', 'Family_Support', 'Month',
#        'Stress_Level'],
#       dtype='object')

# %%
df['Sleep_Hours'].isnull().sum()
# Out:
# np.int64(1333)

# %%
#handling sleeping_hours 
df["Sleep_Hours"].skew()
# Out:
# np.float64(-0.23200645724216598)

# %%
#the the skew value is close to 0 so we can replace it with mean 
df['Sleep_Hours']=df['Sleep_Hours'].fillna(df['Sleep_Hours'].mean())

# %%
df.head()
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       school     6.868702     1.711722            3.176942         NaN
# 1       school     8.519088     3.251084            3.880787   93.978465
# 2      college     4.498770     6.306885            2.936172   64.421253
# 3       school     8.591223     2.384922            5.222832   81.868960
# 4      college     5.329293     9.345179            7.815869   85.847982
#
#    Exam_Pressure  Family_Support  Month  Stress_Level
# 0            8.0             7.0    2.0             1
# 1            6.0             4.0    3.0             1
# 2            7.0             1.0   12.0             1
# 3            2.0             7.0    7.0             0
# 4            5.0             6.0   10.0             1

# %%
#Handling the missing values on study hours
df['Study_Hours'].isnull().sum()
# Out:
# np.int64(1277)

# %%
df["Study_Hours"].skew()
# Out:
# np.float64(0.5548433521388645)

# %%
#though the data is positively skewed over 0.5 so usually i am using median to fill the null values
df['Study_Hours']=df['Study_Hours'].fillna(df['Study_Hours'].median())

# %%
#Handling the missing values on Social_Media_Hours
df['Social_Media_Hours'].isnull().sum()
# Out:
# np.int64(1312)

# %%
df["Social_Media_Hours"].skew()
# Out:
# np.float64(0.25356734284263316)

# %%
#though the data is positively skewed lower than 0.5 so usually i am using mean to fill the null values
df['Social_Media_Hours']=df['Social_Media_Hours'].fillna(df['Social_Media_Hours'].mean())

# %%
#Handling missing values in attendence 

df['Attendance'].isnull().sum()
# Out:
# np.int64(1305)

# %%
df["Attendance"].skew()
# Out:
# np.float64(-1.1267077935524452)

# %%
df['Attendance']=df['Attendance'].fillna(df['Attendance'].median())

# %%
#Handing the missing value for Exam_Pressure 
df['Exam_Pressure'].isnull().sum()
# Out:
# np.int64(1270)

# %%
df["Exam_Pressure"].skew()
# Out:
# np.float64(0.005089404029236175)

# %%
df['Exam_Pressure']=df['Exam_Pressure'].fillna(df['Exam_Pressure'].mean())

# %%
#Family_Support	Month	Stress_Level

# %%
df['Family_Support'].isnull().sum()
# Out:
# np.int64(1291)

# %%
df["Family_Support"].skew()
# Out:
# np.float64(-0.20810318949020373)

# %%
df['Family_Support']=df['Family_Support'].fillna(df['Family_Support'].mean())

# %%
df['Month'].isnull().sum()
# Out:
# np.int64(1314)

# %%
df["Month"].skew()
# Out:
# np.float64(0.005287935477986422)

# %%
df['Month']=df['Month'].fillna(df['Month'].mean())

# %%
df['Stress_Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Stress_Level"].value_counts(normalize=True, dropna=False)
# Out:
# Stress_Level
# 0    0.700118
# 1    0.299882
# Name: proportion, dtype: float64

# %% [markdown]
# train test split

# %%
x=df.drop('Stress_Level',axis=1)
y=df['Stress_Level']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %% [markdown]
# Using onehot encoding for categorical column student type

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

ohe = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')

train_encoded = ohe.fit_transform(x_train[['Student_Type']])
test_encoded = ohe.transform(x_test[['Student_Type']])

train_encoded = pd.DataFrame(
    train_encoded,
    columns=ohe.get_feature_names_out(['Student_Type']),
    index=x_train.index
)

test_encoded = pd.DataFrame(
    test_encoded,
    columns=ohe.get_feature_names_out(['Student_Type']),
    index=x_test.index
)

# %%
x_train = pd.concat(
    [x_train.drop('Student_Type', axis=1), train_encoded],
    axis=1
)

x_test = pd.concat(
    [x_test.drop('Student_Type', axis=1), test_encoded],
    axis=1
)

# %%
x_train.head()
# Out:
#        Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 14053     7.622964     5.323090            3.555614   70.765291
# 11448     6.262499     2.152527            1.061452   83.666304
# 16720     5.340578     5.396863            3.886515   78.490895
# 13822     8.752933     2.074922            5.847674   67.878172
# 24220     5.659666     6.186771            2.327852   81.537216
#
#        Exam_Pressure  Family_Support  Month  Student_Type_school  \
# 14053            8.0             4.0   12.0                  0.0
# 11448           10.0             6.0    3.0                  0.0
# 16720            4.0             6.0   11.0                  0.0
# 13822            7.0             5.0    4.0                  1.0
# 24220            1.0             6.0    9.0                  0.0
#
#        Student_Type_working_student
# 14053                           0.0
# 11448                           0.0
# 16720                           1.0
# 13822                           0.0
# 24220                           0.0

# %% [markdown]
# Using naive bayas

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
gnb = GaussianNB() 
model=gnb.fit(x_train,y_train)
y_pred=model.predict(x_test) 
#print(accuracy_score(y_test,y_pred))
#print(precision_score(y_test,y_pred)) 
print(recall_score(y_test,y_pred)) 
#print(f1_score(y_test,y_pred))
# Out:
# 0.5794212218649518

# %% [markdown]
# using logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

def make_model(x_train,x_test,y_train,y_test):
    model = LogisticRegression(random_state=0, class_weight='balanced')
    model.fit(x_train, y_train)
    
    # Test predictions
    y_pred = model.predict(x_test)
    
    # Train predictions
    y_pred_train = model.predict(x_train)
    
    print("========== TEST ==========")
    print("Accuracy :", accuracy_score(y_test, y_pred))
    print("Precision:", precision_score(y_test, y_pred))
    print("Recall   :", recall_score(y_test, y_pred))
    print("F1 Score :", f1_score(y_test, y_pred))
    print(confusion_matrix(y_test, y_pred))
    
    print("\n========== TRAIN ==========")
    print("Accuracy :", accuracy_score(y_train, y_pred_train))
    print("Precision:", precision_score(y_train, y_pred_train))
    print("Recall   :", recall_score(y_train, y_pred_train))
    print("F1 Score :", f1_score(y_train, y_pred_train))

# %%
make_model(x_train,x_test,y_train,y_test)
# Out:
# ========== TEST ==========
# Accuracy : 0.7805882352941177
# Precision: 0.6076011846001974
# Recall   : 0.7916398713826367
# F1 Score : 0.6875174532253561
# [[2750  795]
#  [ 324 1231]]
#
# ========== TRAIN ==========
# Accuracy : 0.7848529411764706
# Precision: 0.6065840530729754
# Recall   : 0.7954694681549573
# F1 Score : 0.6883033875434983

# %%
#using standard scaler 
from sklearn.preprocessing import StandardScaler 
scale=StandardScaler()
x_train_scale=scale.fit_transform(x_train)
x_test_scale=scale.transform(x_test)
make_model(x_train_scale,x_test_scale,y_train,y_test)
# Out:
# ========== TEST ==========
# Accuracy : 0.7807843137254902
# Precision: 0.6079012345679012
# Recall   : 0.7916398713826367
# F1 Score : 0.6877094972067039
# [[2751  794]
#  [ 324 1231]]
#
# ========== TRAIN ==========
# Accuracy : 0.7847549019607843
# Precision: 0.6064588809613218
# Recall   : 0.7953053184504267
# F1 Score : 0.6881613521766919
